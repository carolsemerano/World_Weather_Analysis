# %% [markdown]
# # Deliverable 1: Retrieve Weather Data

# %%
#Import dependencies
import random
import numpy as np
import requests
import os
import time
import pandas as pd

# Import citipy module
from citipy import citipy

# Import OpenWeatherMap key
from config import weather_api_key

# %%
# Generate ramdom latitude and longitude values
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Create a list with the coordinates
coordinates = list(lat_lngs)

# %%
# Create a list for cities.
cities = []
# Get nearest city for each latitude and longitude.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # Add city, if the it is not in the list
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 756

# %%
# Call API OpenWeatherMap to retrieve following info
# Latitude, longitude, Maximum temperature, Percent humidity, Percent cloudiness, 
# Wind speed, Weather description (for example, clouds, fog, light rain, clear sky)

# OpenWeatherMap API url
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty array for data.
city_data = []

# Start Logging
print("Beginning Data Retrieval \n -----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1

        # Wait 1 minute to restrict the number of calls
        time.sleep(60)

    # Create end URL
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f'Processing Record {record_count} of Set {set_count} | {city}')

    # Add 1 to the record count.
    record_count += 1

    # Make the request using the city_url
    try:
        # Retrieve data as JSON
        city_weather = requests.get(city_url).json()

        # Save data into variables
        lat = city_weather["coord"]["lat"]
        lon = city_weather["coord"]["lon"]
        max_temp = city_weather["main"]["temp_max"]
        humidity = city_weather["main"]["humidity"]
        clouds = city_weather["clouds"]["all"]
        wind = city_weather["wind"]["speed"]
        country = city_weather["sys"]["country"]
        curr_description = city_weather["weather"][0]["description"]

        # Add city info into city_data dictionary.
        city_data.append({"City": city.title(),
                          "Country": country,
                          "Lat": lat,
                          "Lng": lon,
                          "Max Temp": max_temp,
                          "Humidity": humidity,
                          "Cloudiness": clouds,
                          "Wind Speed": wind,
                          "Current Description": curr_description})

    # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Logging Footer.
print("----------------------------- \n Data Retrieval Complete \n-----------------------------")
# Out:
# Beginning Data Retrieval
#  -----------------------------
# Processing Record 1 of Set 1 | coolum beach
# Processing Record 2 of Set 1 | avarua
# Processing Record 3 of Set 1 | inhambane
# Processing Record 4 of Set 1 | north bend
# Processing Record 5 of Set 1 | hilo
# Processing Record 6 of Set 1 | thilogne
# City not found. Skipping...
# Processing Record 7 of Set 1 | umzimvubu
# City not found. Skipping...
# Processing Record 8 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 9 of Set 1 | intipuca
# Processing Record 10 of Set 1 | punta arenas
# Processing Record 11 of Set 1 | cherskiy
# Processing Record 12 of Set 1 | mataura
# Processing Record 13 of Set 1 | kondinskoye
# Processing Record 14 of Set 1 | busselton
# Processing Record 15 of Set 1 | hobart
# Processing Record 16 of Set 1 | bilma
# Processing Record 17 of Set 1 | dikson
# Processing Record 18 of Set 1 | guerrero negro
# Processing Record 19 of Set 1 | albany
# Processing Record 20 of Set 1 | matara
# Processing Record 21 of Set 1 | half moon bay
# Processing Record 22 of Set 1 | rikitea
# Processing Record 23 of Set 1 | hermanus
# Processing Record 24 of Set 1 | mahon
# Processing Record 25 of Set 1 | bluff
# Processing Record 26 of Set 1 | thompson
# Processing Record 27 of Set 1 | saint-philippe
# Processing Record 28 of Set 1 | sao joao da barra
# Processing Record 29 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 30 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 31 of Set 1 | tura
# Processing Record 32 of Set 1 | saint-donat-de-montcalm
# Processing Record 33 of Set 1 | tumannyy
# City not found. Skipping...
# Processing Record 34 of Set 1 | mobaye
# Processing Record 35 of Set 1 | kapaa
# Processing Record 36 of Set 1 | maykain
# City not found. Skipping...
# Processing Record 37 of Set 1 | port alfred
# Processing Record 38 of Set 1 | saint-louis
# Processing Record 39 of Set 1 | rocha
# Processing Record 40 of Set 1 | karaul
# City not found. Skipping...
# Processing Record 41 of Set 1 | bom jesus
# Processing Record 42 of Set 1 | maniwaki
# Processing Record 43 of Set 1 | shimoda
# Processing Record 44 of Set 1 | iquique
# Processing Record 45 of Set 1 | faya
# Processing Record 46 of Set 1 | cabo san lucas
# Processing Record 47 of Set 1 | ushuaia
# Processing Record 48 of Set 1 | quatre cocos
# Processing Record 49 of Set 1 | lata
# Processing Record 50 of Set 1 | khash
# Processing Record 1 of Set 2 | tasiilaq
# Processing Record 2 of Set 2 | hithadhoo
# Processing Record 3 of Set 2 | emerald
# Processing Record 4 of Set 2 | sorvag
# City not found. Skipping...
# Processing Record 5 of Set 2 | provideniya
# Processing Record 6 of Set 2 | esperance
# Processing Record 7 of Set 2 | anadyr
# Processing Record 8 of Set 2 | micoud
# Processing Record 9 of Set 2 | cabedelo
# Processing Record 10 of Set 2 | celestun
# Processing Record 11 of Set 2 | port blair
# Processing Record 12 of Set 2 | naze
# Processing Record 13 of Set 2 | bengkulu
# Processing Record 14 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 15 of Set 2 | pundaguitan
# Processing Record 16 of Set 2 | rincon
# Processing Record 17 of Set 2 | mount isa
# Processing Record 18 of Set 2 | saskylakh
# Processing Record 19 of Set 2 | vao
# Processing Record 20 of Set 2 | butaritari
# Processing Record 21 of Set 2 | norman wells
# Processing Record 22 of Set 2 | bethel
# Processing Record 23 of Set 2 | port lincoln
# Processing Record 24 of Set 2 | tazovskiy
# Processing Record 25 of Set 2 | gurgan
# City not found. Skipping...
# Processing Record 26 of Set 2 | carnarvon
# Processing Record 27 of Set 2 | tarudant
# City not found. Skipping...
# Processing Record 28 of Set 2 | karratha
# Processing Record 29 of Set 2 | sorong
# Processing Record 30 of Set 2 | puerto ayora
# Processing Record 31 of Set 2 | massape
# Processing Record 32 of Set 2 | sabang
# Processing Record 33 of Set 2 | cape town
# Processing Record 34 of Set 2 | salina cruz
# Processing Record 35 of Set 2 | klaksvik
# Processing Record 36 of Set 2 | mar del plata
# Processing Record 37 of Set 2 | rahimatpur
# Processing Record 38 of Set 2 | yellowknife
# Processing Record 39 of Set 2 | analipsis
# Processing Record 40 of Set 2 | aklavik
# Processing Record 41 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 42 of Set 2 | marcona
# City not found. Skipping...
# Processing Record 43 of Set 2 | sinnamary
# Processing Record 44 of Set 2 | wenling
# Processing Record 45 of Set 2 | acapulco
# Processing Record 46 of Set 2 | castro
# Processing Record 47 of Set 2 | mansa
# Processing Record 48 of Set 2 | mae sai
# Processing Record 49 of Set 2 | ponta do sol
# Processing Record 50 of Set 2 | san cristobal
# Processing Record 1 of Set 3 | upernavik
# Processing Record 2 of Set 3 | zavodouspenskoye
# Processing Record 3 of Set 3 | te anau
# Processing Record 4 of Set 3 | rawson
# Processing Record 5 of Set 3 | santa cruz
# Processing Record 6 of Set 3 | victoria
# Processing Record 7 of Set 3 | chokurdakh
# Processing Record 8 of Set 3 | khatanga
# Processing Record 9 of Set 3 | george
# Processing Record 10 of Set 3 | rancho palos verdes
# Processing Record 11 of Set 3 | ponta delgada
# Processing Record 12 of Set 3 | ola
# Processing Record 13 of Set 3 | minervino murge
# Processing Record 14 of Set 3 | isangel
# Processing Record 15 of Set 3 | vichayal
# City not found. Skipping...
# Processing Record 16 of Set 3 | coquimbo
# Processing Record 17 of Set 3 | erie
# Processing Record 18 of Set 3 | cedar city
# Processing Record 19 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 20 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 21 of Set 3 | kadom
# Processing Record 22 of Set 3 | vaini
# Processing Record 23 of Set 3 | netivot
# Processing Record 24 of Set 3 | arraial do cabo
# Processing Record 25 of Set 3 | yantal
# Processing Record 26 of Set 3 | lagoa
# Processing Record 27 of Set 3 | chiang rai
# Processing Record 28 of Set 3 | torbay
# Processing Record 29 of Set 3 | atuona
# Processing Record 30 of Set 3 | mizan teferi
# Processing Record 31 of Set 3 | tual
# Processing Record 32 of Set 3 | sisimiut
# Processing Record 33 of Set 3 | talnakh
# Processing Record 34 of Set 3 | roma
# Processing Record 35 of Set 3 | tessalit
# Processing Record 36 of Set 3 | airai
# Processing Record 37 of Set 3 | kavieng
# Processing Record 38 of Set 3 | nizhneudinsk
# Processing Record 39 of Set 3 | anloga
# Processing Record 40 of Set 3 | bambous virieux
# Processing Record 41 of Set 3 | tuktoyaktuk
# Processing Record 42 of Set 3 | ribeira grande
# Processing Record 43 of Set 3 | salta
# Processing Record 44 of Set 3 | sitka
# Processing Record 45 of Set 3 | istok
# Processing Record 46 of Set 3 | antalaha
# Processing Record 47 of Set 3 | zalantun
# Processing Record 48 of Set 3 | nhulunbuy
# Processing Record 49 of Set 3 | longyearbyen
# Processing Record 50 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 1 of Set 4 | new norfolk
# Processing Record 2 of Set 4 | odweyne
# Processing Record 3 of Set 4 | port elizabeth
# Processing Record 4 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 5 of Set 4 | san carlos de bariloche
# Processing Record 6 of Set 4 | saint-augustin
# Processing Record 7 of Set 4 | jamestown
# Processing Record 8 of Set 4 | nuuk
# Processing Record 9 of Set 4 | hit
# Processing Record 10 of Set 4 | morondava
# Processing Record 11 of Set 4 | severo-kurilsk
# Processing Record 12 of Set 4 | praia da vitoria
# Processing Record 13 of Set 4 | hasaki
# Processing Record 14 of Set 4 | erzin
# Processing Record 15 of Set 4 | imbituba
# Processing Record 16 of Set 4 | nadym
# Processing Record 17 of Set 4 | barrow
# Processing Record 18 of Set 4 | tailai
# Processing Record 19 of Set 4 | porvoo
# Processing Record 20 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 21 of Set 4 | mahebourg
# Processing Record 22 of Set 4 | sibu
# Processing Record 23 of Set 4 | synya
# Processing Record 24 of Set 4 | pontal do parana
# Processing Record 25 of Set 4 | daru
# Processing Record 26 of Set 4 | port augusta
# Processing Record 27 of Set 4 | chernyshevskiy
# Processing Record 28 of Set 4 | boksitogorsk
# Processing Record 29 of Set 4 | santa helena de goias
# Processing Record 30 of Set 4 | sal rei
# Processing Record 31 of Set 4 | geraldton
# Processing Record 32 of Set 4 | formoso do araguaia
# City not found. Skipping...
# Processing Record 33 of Set 4 | beringovskiy
# Processing Record 34 of Set 4 | kruisfontein
# Processing Record 35 of Set 4 | seoul
# Processing Record 36 of Set 4 | codrington
# Processing Record 37 of Set 4 | kumbo
# Processing Record 38 of Set 4 | kahului
# Processing Record 39 of Set 4 | marsh harbour
# Processing Record 40 of Set 4 | chivay
# Processing Record 41 of Set 4 | maningrida
# Processing Record 42 of Set 4 | el colorado
# Processing Record 43 of Set 4 | hobyo
# Processing Record 44 of Set 4 | carutapera
# Processing Record 45 of Set 4 | axim
# Processing Record 46 of Set 4 | benguela
# Processing Record 47 of Set 4 | pisco
# Processing Record 48 of Set 4 | kot addu
# Processing Record 49 of Set 4 | preobrazheniye
# Processing Record 50 of Set 4 | santa maria del oro
# Processing Record 1 of Set 5 | khorixas
# Processing Record 2 of Set 5 | kizhinga
# Processing Record 3 of Set 5 | saint george
# Processing Record 4 of Set 5 | constitucion
# Processing Record 5 of Set 5 | kaitangata
# Processing Record 6 of Set 5 | fort saint john
# City not found. Skipping...
# Processing Record 7 of Set 5 | macaboboni
# City not found. Skipping...
# Processing Record 8 of Set 5 | kaohsiung
# Processing Record 9 of Set 5 | martil
# Processing Record 10 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 11 of Set 5 | nishihara
# Processing Record 12 of Set 5 | sundsvall
# Processing Record 13 of Set 5 | presidencia roque saenz pena
# Processing Record 14 of Set 5 | ranong
# Processing Record 15 of Set 5 | mayumba
# Processing Record 16 of Set 5 | nikolskoye
# Processing Record 17 of Set 5 | dunedin
# Processing Record 18 of Set 5 | port arthur
# Processing Record 19 of Set 5 | pevek
# Processing Record 20 of Set 5 | denpasar
# Processing Record 21 of Set 5 | kavaratti
# Processing Record 22 of Set 5 | gavrilovka vtoraya
# Processing Record 23 of Set 5 | dwarka
# Processing Record 24 of Set 5 | vila
# Processing Record 25 of Set 5 | zhenhai
# Processing Record 26 of Set 5 | saldanha
# Processing Record 27 of Set 5 | narsaq
# Processing Record 28 of Set 5 | taoudenni
# Processing Record 29 of Set 5 | conneaut
# Processing Record 30 of Set 5 | cidreira
# Processing Record 31 of Set 5 | pemangkat
# Processing Record 32 of Set 5 | east london
# Processing Record 33 of Set 5 | alice springs
# Processing Record 34 of Set 5 | dingle
# Processing Record 35 of Set 5 | sao filipe
# Processing Record 36 of Set 5 | kota kinabalu
# Processing Record 37 of Set 5 | erenhot
# Processing Record 38 of Set 5 | nemuro
# Processing Record 39 of Set 5 | cap malheureux
# Processing Record 40 of Set 5 | belmonte
# Processing Record 41 of Set 5 | meulaboh
# Processing Record 42 of Set 5 | walvis bay
# Processing Record 43 of Set 5 | mnogovershinnyy
# Processing Record 44 of Set 5 | faanui
# Processing Record 45 of Set 5 | los llanos de aridane
# Processing Record 46 of Set 5 | kargasok
# Processing Record 47 of Set 5 | hami
# Processing Record 48 of Set 5 | tevriz
# Processing Record 49 of Set 5 | makakilo city
# Processing Record 50 of Set 5 | laem sing
# Processing Record 1 of Set 6 | lavrentiya
# Processing Record 2 of Set 6 | cayenne
# Processing Record 3 of Set 6 | jumla
# Processing Record 4 of Set 6 | araouane
# Processing Record 5 of Set 6 | korgen
# Processing Record 6 of Set 6 | namibe
# Processing Record 7 of Set 6 | flin flon
# Processing Record 8 of Set 6 | segou
# Processing Record 9 of Set 6 | nurobod
# Processing Record 10 of Set 6 | stromness
# Processing Record 11 of Set 6 | gladstone
# Processing Record 12 of Set 6 | tshikapa
# Processing Record 13 of Set 6 | sakakah
# Processing Record 14 of Set 6 | paramonga
# Processing Record 15 of Set 6 | alofi
# Processing Record 16 of Set 6 | okha
# Processing Record 17 of Set 6 | hualmay
# Processing Record 18 of Set 6 | georgetown
# Processing Record 19 of Set 6 | charters towers
# Processing Record 20 of Set 6 | badarpur
# Processing Record 21 of Set 6 | forestville
# Processing Record 22 of Set 6 | hope
# Processing Record 23 of Set 6 | broome
# Processing Record 24 of Set 6 | arlit
# Processing Record 25 of Set 6 | fort-shevchenko
# Processing Record 26 of Set 6 | jinka
# Processing Record 27 of Set 6 | wamba
# Processing Record 28 of Set 6 | coos bay
# Processing Record 29 of Set 6 | alyangula
# Processing Record 30 of Set 6 | betare oya
# Processing Record 31 of Set 6 | kirovskiy
# Processing Record 32 of Set 6 | iqaluit
# Processing Record 33 of Set 6 | galgani
# City not found. Skipping...
# Processing Record 34 of Set 6 | punta alta
# Processing Record 35 of Set 6 | kirya
# Processing Record 36 of Set 6 | kuche
# City not found. Skipping...
# Processing Record 37 of Set 6 | souillac
# Processing Record 38 of Set 6 | ukiah
# Processing Record 39 of Set 6 | dicabisagan
# Processing Record 40 of Set 6 | le port
# Processing Record 41 of Set 6 | duiwelskloof
# Processing Record 42 of Set 6 | tautira
# Processing Record 43 of Set 6 | meadow lake
# Processing Record 44 of Set 6 | bonavista
# Processing Record 45 of Set 6 | srednekolymsk
# Processing Record 46 of Set 6 | bredasdorp
# Processing Record 47 of Set 6 | mabaruma
# Processing Record 48 of Set 6 | phan thiet
# Processing Record 49 of Set 6 | omboue
# Processing Record 50 of Set 6 | morant bay
# Processing Record 1 of Set 7 | vitim
# Processing Record 2 of Set 7 | kutum
# Processing Record 3 of Set 7 | padang
# Processing Record 4 of Set 7 | davila
# Processing Record 5 of Set 7 | tiksi
# Processing Record 6 of Set 7 | kodiak
# Processing Record 7 of Set 7 | illela
# Processing Record 8 of Set 7 | nyirvasvari
# Processing Record 9 of Set 7 | bathsheba
# Processing Record 10 of Set 7 | tete
# Processing Record 11 of Set 7 | maragogi
# Processing Record 12 of Set 7 | lompoc
# Processing Record 13 of Set 7 | surt
# Processing Record 14 of Set 7 | marrakesh
# Processing Record 15 of Set 7 | halifax
# Processing Record 16 of Set 7 | mae chan
# Processing Record 17 of Set 7 | westport
# Processing Record 18 of Set 7 | blythe
# Processing Record 19 of Set 7 | jacareacanga
# Processing Record 20 of Set 7 | vila velha
# Processing Record 21 of Set 7 | hofn
# Processing Record 22 of Set 7 | fort nelson
# Processing Record 23 of Set 7 | fuyang
# Processing Record 24 of Set 7 | honiara
# Processing Record 25 of Set 7 | perth
# Processing Record 26 of Set 7 | old saybrook
# Processing Record 27 of Set 7 | kedougou
# Processing Record 28 of Set 7 | bilibino
# Processing Record 29 of Set 7 | avera
# Processing Record 30 of Set 7 | suez
# Processing Record 31 of Set 7 | nisia floresta
# Processing Record 32 of Set 7 | kupang
# Processing Record 33 of Set 7 | burica
# City not found. Skipping...
# Processing Record 34 of Set 7 | beaverlodge
# Processing Record 35 of Set 7 | berbera
# Processing Record 36 of Set 7 | qaanaaq
# Processing Record 37 of Set 7 | mitchell
# Processing Record 38 of Set 7 | bengbu
# Processing Record 39 of Set 7 | sovetskiy
# Processing Record 40 of Set 7 | luderitz
# Processing Record 41 of Set 7 | hovd
# Processing Record 42 of Set 7 | havre-saint-pierre
# Processing Record 43 of Set 7 | channel-port aux basques
# Processing Record 44 of Set 7 | abu dhabi
# Processing Record 45 of Set 7 | lahaina
# Processing Record 46 of Set 7 | road town
# Processing Record 47 of Set 7 | shizunai
# Processing Record 48 of Set 7 | mugur-aksy
# Processing Record 49 of Set 7 | komsomolskiy
# Processing Record 50 of Set 7 | sabirabad
# Processing Record 1 of Set 8 | general pico
# Processing Record 2 of Set 8 | saint anthony
# Processing Record 3 of Set 8 | isiro
# Processing Record 4 of Set 8 | mirzapur
# Processing Record 5 of Set 8 | wanxian
# Processing Record 6 of Set 8 | lengshuijiang
# Processing Record 7 of Set 8 | trairi
# Processing Record 8 of Set 8 | ajdabiya
# Processing Record 9 of Set 8 | nador
# Processing Record 10 of Set 8 | ushtobe
# Processing Record 11 of Set 8 | namie
# Processing Record 12 of Set 8 | torbat-e jam
# Processing Record 13 of Set 8 | itoman
# Processing Record 14 of Set 8 | auki
# Processing Record 15 of Set 8 | general roca
# Processing Record 16 of Set 8 | san patricio
# Processing Record 17 of Set 8 | rio gallegos
# Processing Record 18 of Set 8 | eureka
# Processing Record 19 of Set 8 | puyo
# Processing Record 20 of Set 8 | marzuq
# Processing Record 21 of Set 8 | obluche
# City not found. Skipping...
# Processing Record 22 of Set 8 | otane
# Processing Record 23 of Set 8 | fortuna
# Processing Record 24 of Set 8 | attawapiskat
# City not found. Skipping...
# Processing Record 25 of Set 8 | inta
# Processing Record 26 of Set 8 | lebu
# Processing Record 27 of Set 8 | bagdarin
# Processing Record 28 of Set 8 | yabelo
# Processing Record 29 of Set 8 | amahai
# Processing Record 30 of Set 8 | weiswampach
# Processing Record 31 of Set 8 | bumba
# Processing Record 32 of Set 8 | poum
# Processing Record 33 of Set 8 | kegayli
# City not found. Skipping...
# Processing Record 34 of Set 8 | higuey
# City not found. Skipping...
# Processing Record 35 of Set 8 | maceio
# Processing Record 36 of Set 8 | laguna
# Processing Record 37 of Set 8 | sorland
# Processing Record 38 of Set 8 | ekhabi
# Processing Record 39 of Set 8 | zelenogorskiy
# Processing Record 40 of Set 8 | oranjemund
# Processing Record 41 of Set 8 | coihaique
# Processing Record 42 of Set 8 | conway
# Processing Record 43 of Set 8 | maldonado
# Processing Record 44 of Set 8 | edd
# Processing Record 45 of Set 8 | balkanabat
# Processing Record 46 of Set 8 | kununurra
# Processing Record 47 of Set 8 | colares
# Processing Record 48 of Set 8 | yaan
# Processing Record 49 of Set 8 | tuatapere
# Processing Record 50 of Set 8 | andselv
# City not found. Skipping...
# Processing Record 1 of Set 9 | lorengau
# Processing Record 2 of Set 9 | asau
# Processing Record 3 of Set 9 | leningradskiy
# Processing Record 4 of Set 9 | gazojak
# Processing Record 5 of Set 9 | maniitsoq
# Processing Record 6 of Set 9 | ilulissat
# Processing Record 7 of Set 9 | yumen
# Processing Record 8 of Set 9 | tamarac
# Processing Record 9 of Set 9 | griffith
# Processing Record 10 of Set 9 | flinders
# Processing Record 11 of Set 9 | norfolk
# Processing Record 12 of Set 9 | yumbe
# Processing Record 13 of Set 9 | tahta
# Processing Record 14 of Set 9 | salalah
# Processing Record 15 of Set 9 | gambela
# Processing Record 16 of Set 9 | adre
# Processing Record 17 of Set 9 | yulara
# Processing Record 18 of Set 9 | progreso
# Processing Record 19 of Set 9 | hagerstown
# Processing Record 20 of Set 9 | cusset
# Processing Record 21 of Set 9 | sibolga
# Processing Record 22 of Set 9 | buraydah
# Processing Record 23 of Set 9 | atar
# Processing Record 24 of Set 9 | camacupa
# Processing Record 25 of Set 9 | college
# Processing Record 26 of Set 9 | vardo
# Processing Record 27 of Set 9 | terre haute
# Processing Record 28 of Set 9 | kamenka
# Processing Record 29 of Set 9 | broken hill
# Processing Record 30 of Set 9 | grand gaube
# Processing Record 31 of Set 9 | bababe
# City not found. Skipping...
# Processing Record 32 of Set 9 | pirapora
# Processing Record 33 of Set 9 | tanggu
# Processing Record 34 of Set 9 | ilhabela
# Processing Record 35 of Set 9 | khani
# Processing Record 36 of Set 9 | elbasan
# Processing Record 37 of Set 9 | lakheri
# Processing Record 38 of Set 9 | wahran
# City not found. Skipping...
# Processing Record 39 of Set 9 | saint-francois
# Processing Record 40 of Set 9 | mango
# Processing Record 41 of Set 9 | kitui
# Processing Record 42 of Set 9 | shasta lake
# Processing Record 43 of Set 9 | keningau
# Processing Record 44 of Set 9 | popondetta
# Processing Record 45 of Set 9 | katsuura
# Processing Record 46 of Set 9 | pangody
# Processing Record 47 of Set 9 | kagoro
# Processing Record 48 of Set 9 | pahalgam
# Processing Record 49 of Set 9 | kaman
# Processing Record 50 of Set 9 | la cumbre
# Processing Record 1 of Set 10 | clyde river
# Processing Record 2 of Set 10 | colwyn bay
# Processing Record 3 of Set 10 | shingu
# Processing Record 4 of Set 10 | batsfjord
# Processing Record 5 of Set 10 | carballo
# Processing Record 6 of Set 10 | gangotri
# City not found. Skipping...
# Processing Record 7 of Set 10 | merritt island
# Processing Record 8 of Set 10 | ust-kuyga
# Processing Record 9 of Set 10 | coahuayana
# Processing Record 10 of Set 10 | columbio
# Processing Record 11 of Set 10 | mahibadhoo
# Processing Record 12 of Set 10 | devonport
# Processing Record 13 of Set 10 | at-bashi
# Processing Record 14 of Set 10 | san policarpo
# Processing Record 15 of Set 10 | madaoua
# Processing Record 16 of Set 10 | ruwi
# Processing Record 17 of Set 10 | nanortalik
# Processing Record 18 of Set 10 | olinda
# Processing Record 19 of Set 10 | louisbourg
# City not found. Skipping...
# Processing Record 20 of Set 10 | miri
# Processing Record 21 of Set 10 | christchurch
# Processing Record 22 of Set 10 | muhos
# Processing Record 23 of Set 10 | doha
# Processing Record 24 of Set 10 | paraguacu paulista
# Processing Record 25 of Set 10 | ofunato
# Processing Record 26 of Set 10 | plettenberg bay
# Processing Record 27 of Set 10 | chuy
# Processing Record 28 of Set 10 | srandakan
# Processing Record 29 of Set 10 | kiunga
# Processing Record 30 of Set 10 | nhamunda
# Processing Record 31 of Set 10 | svetlyy
# Processing Record 32 of Set 10 | lyubeshiv
# City not found. Skipping...
# Processing Record 33 of Set 10 | anzhero-sudzhensk
# Processing Record 34 of Set 10 | sur
# Processing Record 35 of Set 10 | jijiga
# Processing Record 36 of Set 10 | mykhaylivka
# Processing Record 37 of Set 10 | heihe
# Processing Record 38 of Set 10 | sandviken
# Processing Record 39 of Set 10 | lagunas
# Processing Record 40 of Set 10 | sola
# Processing Record 41 of Set 10 | caravelas
# Processing Record 42 of Set 10 | suwannaphum
# Processing Record 43 of Set 10 | nome
# Processing Record 44 of Set 10 | namtsy
# Processing Record 45 of Set 10 | pacific grove
# Processing Record 46 of Set 10 | pendleton
# Processing Record 47 of Set 10 | abiy adi
# City not found. Skipping...
# Processing Record 48 of Set 10 | puerto escondido
# Processing Record 49 of Set 10 | coacoyul
# Processing Record 50 of Set 10 | satitoa
# City not found. Skipping...
# Processing Record 1 of Set 11 | warqla
# City not found. Skipping...
# Processing Record 2 of Set 11 | itarema
# Processing Record 3 of Set 11 | chau doc
# Processing Record 4 of Set 11 | suntar
# Processing Record 5 of Set 11 | mantua
# Processing Record 6 of Set 11 | lagos
# Processing Record 7 of Set 11 | uruzgan
# Processing Record 8 of Set 11 | aitape
# Processing Record 9 of Set 11 | samur
# Processing Record 10 of Set 11 | grootfontein
# Processing Record 11 of Set 11 | dongying
# Processing Record 12 of Set 11 | hambantota
# Processing Record 13 of Set 11 | pangnirtung
# Processing Record 14 of Set 11 | karakol
# Processing Record 15 of Set 11 | port said
# Processing Record 16 of Set 11 | oum hadjer
# Processing Record 17 of Set 11 | gornozavodsk
# Processing Record 18 of Set 11 | mmathubudukwane
# Processing Record 19 of Set 11 | koumac
# Processing Record 20 of Set 11 | vila franca do campo
# Processing Record 21 of Set 11 | muscat
# Processing Record 22 of Set 11 | aripuana
# Processing Record 23 of Set 11 | hashtgerd
# Processing Record 24 of Set 11 | wau
# Processing Record 25 of Set 11 | grand centre
# City not found. Skipping...
# Processing Record 26 of Set 11 | namatanai
# Processing Record 27 of Set 11 | shadrinsk
# Processing Record 28 of Set 11 | zhanatas
# City not found. Skipping...
# Processing Record 29 of Set 11 | toshkivka
# Processing Record 30 of Set 11 | grindavik
# Processing Record 31 of Set 11 | smithers
# Processing Record 32 of Set 11 | leh
# Processing Record 33 of Set 11 | kuytun
# Processing Record 34 of Set 11 | vostok
# Processing Record 35 of Set 11 | mariental
# Processing Record 36 of Set 11 | dickson
# Processing Record 37 of Set 11 | dubenskiy
# City not found. Skipping...
# Processing Record 38 of Set 11 | kulhudhuffushi
# Processing Record 39 of Set 11 | rungata
# City not found. Skipping...
# Processing Record 40 of Set 11 | mendahara
# City not found. Skipping...
# Processing Record 41 of Set 11 | liberal
# Processing Record 42 of Set 11 | pacasmayo
# Processing Record 43 of Set 11 | sao felix do xingu
# Processing Record 44 of Set 11 | wajir
# Processing Record 45 of Set 11 | saleaula
# City not found. Skipping...
# Processing Record 46 of Set 11 | jati
# Processing Record 47 of Set 11 | dunhua
# Processing Record 48 of Set 11 | mayo
# Processing Record 49 of Set 11 | kachiry
# Processing Record 50 of Set 11 | notse
# Processing Record 1 of Set 12 | bowen
# Processing Record 2 of Set 12 | mattru
# Processing Record 3 of Set 12 | ust-barguzin
# Processing Record 4 of Set 12 | banamba
# Processing Record 5 of Set 12 | bandarbeyla
# Processing Record 6 of Set 12 | bosobolo
# Processing Record 7 of Set 12 | najran
# Processing Record 8 of Set 12 | tarko-sale
# Processing Record 9 of Set 12 | pochutla
# Processing Record 10 of Set 12 | aberfeldy
# Processing Record 11 of Set 12 | bani walid
# Processing Record 12 of Set 12 | borzya
# Processing Record 13 of Set 12 | talaya
# Processing Record 14 of Set 12 | beni
# Processing Record 15 of Set 12 | puerto del rosario
# Processing Record 16 of Set 12 | ahipara
# Processing Record 17 of Set 12 | zhezkazgan
# Processing Record 18 of Set 12 | ankazoabo
# Processing Record 19 of Set 12 | tigil
# Processing Record 20 of Set 12 | bolungarvik
# City not found. Skipping...
# Processing Record 21 of Set 12 | hereford
# Processing Record 22 of Set 12 | sangar
# Processing Record 23 of Set 12 | puerto madryn
# Processing Record 24 of Set 12 | tutoia
# Processing Record 25 of Set 12 | mozarlandia
# Processing Record 26 of Set 12 | svetlogorsk
# Processing Record 27 of Set 12 | fukue
# Processing Record 28 of Set 12 | redcliffe
# Processing Record 29 of Set 12 | samarai
# Processing Record 30 of Set 12 | adrar
# Processing Record 31 of Set 12 | hay river
# Processing Record 32 of Set 12 | amapa
# Processing Record 33 of Set 12 | twin falls
# Processing Record 34 of Set 12 | siguiri
# Processing Record 35 of Set 12 | jagdalpur
# Processing Record 36 of Set 12 | ancud
# Processing Record 37 of Set 12 | luanda
# Processing Record 38 of Set 12 | dzitbalche
# Processing Record 39 of Set 12 | nalut
# Processing Record 40 of Set 12 | kiruna
# Processing Record 41 of Set 12 | barentu
# Processing Record 42 of Set 12 | sumter
# Processing Record 43 of Set 12 | kudahuvadhoo
# Processing Record 44 of Set 12 | aswan
# Processing Record 45 of Set 12 | providencia
# Processing Record 46 of Set 12 | luganville
# Processing Record 47 of Set 12 | altay
# Processing Record 48 of Set 12 | phangnga
# Processing Record 49 of Set 12 | namuac
# Processing Record 50 of Set 12 | jackson
# Processing Record 1 of Set 13 | curaca
# Processing Record 2 of Set 13 | katsiveli
# City not found. Skipping...
# Processing Record 3 of Set 13 | gainesville
# Processing Record 4 of Set 13 | touros
# Processing Record 5 of Set 13 | ismailia
# Processing Record 6 of Set 13 | marystown
# Processing Record 7 of Set 13 | jardim
# Processing Record 8 of Set 13 | vanimo
# Processing Record 9 of Set 13 | ust-tsilma
# Processing Record 10 of Set 13 | dauphin
# Processing Record 11 of Set 13 | the pas
# Processing Record 12 of Set 13 | santa maria
# Processing Record 13 of Set 13 | santiago
# Processing Record 14 of Set 13 | gimli
# Processing Record 15 of Set 13 | tiarei
# Processing Record 16 of Set 13 | kirakira
# Processing Record 17 of Set 13 | camana
# Processing Record 18 of Set 13 | honningsvag
# Processing Record 19 of Set 13 | kysyl-syr
# Processing Record 20 of Set 13 | baruun-urt
# Processing Record 21 of Set 13 | huarmey
# Processing Record 22 of Set 13 | marsa matruh
# Processing Record 23 of Set 13 | usakos
# Processing Record 24 of Set 13 | witrivier
# City not found. Skipping...
# Processing Record 25 of Set 13 | paamiut
# Processing Record 26 of Set 13 | badin
# Processing Record 27 of Set 13 | la libertad
# Processing Record 28 of Set 13 | haines junction
# Processing Record 29 of Set 13 | ketchikan
# Processing Record 30 of Set 13 | dongli
# Processing Record 31 of Set 13 | cumaribo
# City not found. Skipping...
# Processing Record 32 of Set 13 | olafsvik
# Processing Record 33 of Set 13 | umm kaddadah
# Processing Record 34 of Set 13 | lander
# Processing Record 35 of Set 13 | takahashi
# Processing Record 36 of Set 13 | rabo de peixe
# Processing Record 37 of Set 13 | chalus
# Processing Record 38 of Set 13 | ulaanbaatar
# Processing Record 39 of Set 13 | zhongxing
# Processing Record 40 of Set 13 | salamiyah
# Processing Record 41 of Set 13 | silopi
# Processing Record 42 of Set 13 | graaff-reinet
# Processing Record 43 of Set 13 | san quintin
# Processing Record 44 of Set 13 | grand-santi
# Processing Record 45 of Set 13 | wright
# Processing Record 46 of Set 13 | sherbakul
# Processing Record 47 of Set 13 | teningen
# Processing Record 48 of Set 13 | borba
# Processing Record 49 of Set 13 | amga
# Processing Record 50 of Set 13 | mount gambier
# Processing Record 1 of Set 14 | teguise
# Processing Record 2 of Set 14 | ribas do rio pardo
# Processing Record 3 of Set 14 | umm lajj
# Processing Record 4 of Set 14 | kloulklubed
# Processing Record 5 of Set 14 | tezu
# Processing Record 6 of Set 14 | buchanan
# Processing Record 7 of Set 14 | jha jha
# Processing Record 8 of Set 14 | wajima
# Processing Record 9 of Set 14 | salinas
# Processing Record 10 of Set 14 | elko
# Processing Record 11 of Set 14 | srivardhan
# Processing Record 12 of Set 14 | uwayl
# City not found. Skipping...
# Processing Record 13 of Set 14 | anuradhapura
# Processing Record 14 of Set 14 | tarhunah
# City not found. Skipping...
# Processing Record 15 of Set 14 | bocaranga
# City not found. Skipping...
# Processing Record 16 of Set 14 | millau
# Processing Record 17 of Set 14 | belyy yar
# Processing Record 18 of Set 14 | auch
# Processing Record 19 of Set 14 | kerrobert
# Processing Record 20 of Set 14 | tilichiki
# Processing Record 21 of Set 14 | peski
# Processing Record 22 of Set 14 | deputatskiy
# Processing Record 23 of Set 14 | romny
# Processing Record 24 of Set 14 | pecos
# Processing Record 25 of Set 14 | hvide sande
# Processing Record 26 of Set 14 | baoma
# Processing Record 27 of Set 14 | kaeo
# Processing Record 28 of Set 14 | nyurba
# Processing Record 29 of Set 14 | calama
# Processing Record 30 of Set 14 | mangrol
# Processing Record 31 of Set 14 | klaebu
# Processing Record 32 of Set 14 | turtkul
# City not found. Skipping...
# Processing Record 33 of Set 14 | bukachacha
# Processing Record 34 of Set 14 | iwanai
# Processing Record 35 of Set 14 | turayf
# Processing Record 36 of Set 14 | mareeba
# Processing Record 37 of Set 14 | cascais
# Processing Record 38 of Set 14 | shenjiamen
# Processing Record 39 of Set 14 | kamenskoye
# City not found. Skipping...
# Processing Record 40 of Set 14 | saint stephen
# Processing Record 41 of Set 14 | wembley
# Processing Record 42 of Set 14 | barbar
# City not found. Skipping...
# Processing Record 43 of Set 14 | sumbe
# Processing Record 44 of Set 14 | zhanaozen
# Processing Record 45 of Set 14 | oyem
# Processing Record 46 of Set 14 | jizan
# Processing Record 47 of Set 14 | beyneu
# Processing Record 48 of Set 14 | vestmanna
# Processing Record 49 of Set 14 | nouadhibou
# Processing Record 50 of Set 14 | wuda
# Processing Record 1 of Set 15 | tabuk
# Processing Record 2 of Set 15 | nara
# Processing Record 3 of Set 15 | lalibela
# Processing Record 4 of Set 15 | bonfim
# Processing Record 5 of Set 15 | guatire
# Processing Record 6 of Set 15 | puerto carreno
# Processing Record 7 of Set 15 | teya
# Processing Record 8 of Set 15 | matane
# Processing Record 9 of Set 15 | payakumbuh
# Processing Record 10 of Set 15 | zhangye
# Processing Record 11 of Set 15 | mirante do paranapanema
# Processing Record 12 of Set 15 | polson
# Processing Record 13 of Set 15 | lewistown
# Processing Record 14 of Set 15 | ahuimanu
# Processing Record 15 of Set 15 | richards bay
# Processing Record 16 of Set 15 | wagar
# Processing Record 17 of Set 15 | mocuba
# Processing Record 18 of Set 15 | mpika
# Processing Record 19 of Set 15 | saint-leu
# Processing Record 20 of Set 15 | lucapa
# Processing Record 21 of Set 15 | lubao
# Processing Record 22 of Set 15 | wanning
# Processing Record 23 of Set 15 | mwense
# Processing Record 24 of Set 15 | yugorsk
# Processing Record 25 of Set 15 | viligili
# City not found. Skipping...
# Processing Record 26 of Set 15 | tambura
# Processing Record 27 of Set 15 | montepuez
# Processing Record 28 of Set 15 | espinosa
# Processing Record 29 of Set 15 | callaway
# Processing Record 30 of Set 15 | tres picos
# Processing Record 31 of Set 15 | vilhena
# Processing Record 32 of Set 15 | kjollefjord
# Processing Record 33 of Set 15 | dudinka
# Processing Record 34 of Set 15 | kresttsy
# Processing Record 35 of Set 15 | gat
# Processing Record 36 of Set 15 | buluang
# Processing Record 37 of Set 15 | omsukchan
# Processing Record 38 of Set 15 | tabiauea
# City not found. Skipping...
# Processing Record 39 of Set 15 | hongjiang
# Processing Record 40 of Set 15 | jalu
# Processing Record 41 of Set 15 | snasa
# Processing Record 42 of Set 15 | xalpatlahuac
# Processing Record 43 of Set 15 | kichera
# Processing Record 44 of Set 15 | male
# Processing Record 45 of Set 15 | galle
# Processing Record 46 of Set 15 | ngunguru
# Processing Record 47 of Set 15 | saquarema
# Processing Record 48 of Set 15 | yerofey pavlovich
# Processing Record 49 of Set 15 | buala
# Processing Record 50 of Set 15 | kazalinsk
# City not found. Skipping...
# Processing Record 1 of Set 16 | salym
# Processing Record 2 of Set 16 | ubon ratchathani
# Processing Record 3 of Set 16 | savonlinna
# Processing Record 4 of Set 16 | chapais
# Processing Record 5 of Set 16 | praia
# Processing Record 6 of Set 16 | shiyan
# -----------------------------
#  Data Retrieval Complete
# -----------------------------

# %%
# Convert the array into DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Coolum Beach      AU -26.5333  153.1000     69.12        92          70
# 1        Avarua      CK -21.2078 -159.7750     82.45        78          40
# 2     Inhambane      MZ -23.8650   35.3833     76.03        89           1
# 3    North Bend      US  43.4065 -124.2243     48.85        85          75
# 4          Hilo      US  19.7297 -155.0900     80.28        89         100
# 5      Intipuca      SV  13.1969  -88.0544     94.91        37          16
# 6  Punta Arenas      CL -53.1500  -70.9167     50.11        62          40
# 7      Cherskiy      RU  68.7500  161.3000     -1.70        85          97
# 8       Mataura      NZ -46.1927  168.8643     48.47        90          82
# 9   Kondinskoye      RU  59.6481   67.4100     31.86        97         100
#
#    Wind Speed Current Description
# 0        7.90       broken clouds
# 1        3.44    scattered clouds
# 2        5.30           clear sky
# 3       10.36       broken clouds
# 4        6.91          light rain
# 5        9.24          few clouds
# 6       32.21    scattered clouds
# 7        3.89     overcast clouds
# 8        2.48       broken clouds
# 9        5.57     overcast clouds

# %%
# Create a CSV file.
output_file = "WeatherPy_Database.csv"

# Save the data frame into the CSV file.
city_data_df.to_csv(output_file, index_label="City_ID")
